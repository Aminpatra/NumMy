# %%
import numpy as np

# %%
l = np.array([[[[[1,2,3]]]]])
print(l.shape)
# Out:
# (1, 1, 1, 1, 3)

# %%
d0 = []
d1 = [1,2,3,4]
d2 = [[1,2],
      [3,4]]
d3 = [[[1, 2, 3],
      [1, 2, 3]]]
d4 = [[[[[1,2,3]]]]]
d_not = [[1, 2], [3]]

print(np.array(d0).shape)
print(np.array(d1).shape)
print(np.array(d2).shape)
print(np.array(d3).shape)
print(np.array(d4).shape)
# print(np.array(d_not).shape)
# Out:
# (0,)
# (4,)
# (2, 2)
# (1, 2, 3)
# (1, 1, 1, 1, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 15
#      13 print(np.array(d3).shape)
#      14 print(np.array(d4).shape)
# ---> 15 print(np.array(d_not).shape)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.

# %%
List = [[[1, 2, 3],
      [1, 2, 3]]]
shape = []

lst = List[0]

while (isinstance(lst, List)):
  print(lst)
  lst =
# Out:
# [[1, 2, 3], [1, 2, 3]]
# []

# %%
d = {1: 'one', 2: 'two'}
np.array(d)
# Out:
# array({1: 'one', 2: 'two'}, dtype=object)

# %%
def fact(n):
  
  if n == 1:
    return 1
  
  return n * fact(n-1)


print(fact(5))
# Out:
# 120

# %%
def arr_shape(List, shape = None):

  if shape is None:
    shape = []

  if not isinstance(List, list) or not List:
    return shape
  
  shape.append(len(List))
  
  return arr_shape(List[0], shape)

print(arr_shape(d1))
print(arr_shape(d2))
print(arr_shape(d3))
print(arr_shape(d_not))
# Out:
# [4]
# [2, 2]
# [1, 2, 3]
# [2, 2]
